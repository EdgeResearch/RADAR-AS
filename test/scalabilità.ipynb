# %%
import matplotlib
ndoes = [100,250,500,750,1000]
without_SA = [2,4,9,16,25]
with_SA = [36,112,295,578,885]

# %%
import numpy as np
import matplotlib.pyplot as plt

# evenly sampled time at 200ms intervals
# red dashes, blue squares and green triangles
plt.plot(ndoes, without_SA, label="Without SA")
plt.plot(ndoes, with_SA, label="With SA")
plt.legend()
plt.xlabel("Number of Nodes")
plt.ylabel("Time (Minutes)")

plt.savefig("scalability.png")
plt.show()
